# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('KMA').getOrCreate()
from pyspark.ml.clustering import KMeans
from pyspark.ml.feature import VectorAssembler
import os
import time
import pandas as pd
import numpy as np

import boto3
from io import BytesIO
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role

# %%
'''
-----------------------------------------------------------------------------
--- Inptuts
-----------------------------------------------------------------------------
'''
dataSource = 'L4'
Interp = 'Interp'
dataSetName = 'L4polarInterpDataScaled.csv'
Dimensions = 1
Coor = 'Polar'

clusterRange1 = range(2,101,1)
clusterRange2 = range(105,501,5)

# %%
'''
-----------------------------------------------------------------------------
--- Definitions
-----------------------------------------------------------------------------
'''
Results = 'Results'
Indicies = 'Indicies'
Analysis = 'KMA'
resultsPath = '{}/{}/{}/{}/{}/{}/'.format(dataSource,Coor,Interp,Analysis,Results,Dimensions)

# Configuring S3
s3_bucket_name = 'jasper-ml-sagemaker'
role = get_execution_role()

client = boto3.client('s3')
resource = boto3.resource('s3')
my_bucket = resource.Bucket(s3_bucket_name)

# %%
'''
-----------------------------------------------------------------------------
--- Importing and Vectorising Data
-----------------------------------------------------------------------------
'''

dataPath = 'Data/'
dataKey = dataSetName
obj = client.get_object(Bucket=s3_bucket_name, Key=dataPath + dataKey)
dataSet2 = pd.read_csv(obj['Body'], header = None, index_col=None)
dataSet2.to_csv(dataKey, index=False)
dataset = spark.read.csv(dataKey,inferSchema = True)

assembler = VectorAssembler(inputCols= dataset.columns,
                           outputCol = 'features')
final_data = assembler.transform(dataset)

'''
-----------------------------------------------------------------------------
--- Performing Clustering
-----------------------------------------------------------------------------
'''
collectedIndicies = [] 
for i in clusterRange1:
    #  Perform Kmeans on the data
    timestart = time.time()
    kmeans = KMeans(k=i, maxIter= 2000,featuresCol='features')
    kMeansModel = kmeans.fit(final_data)
    predictions = kMeansModel.transform(final_data).select('prediction').toPandas()

    # save at each stage to reduce memory consumption
    dataKey = '{}results.csv'.format(i)
    predictions.to_csv(dataKey, index=False)
    my_bucket.upload_file(dataKey,Key=resultsPath + dataKey)
    os.remove(dataKey)
    
    # Calculate Char Indicies
    profile2 = dataSet2.copy()
    profile2['labels'] = predictions.astype(np.float64)
    charProfile = profile2.groupby(['labels']).mean().values
    characteristicIndicies = []
    for j in range(i):
        characteristicIndicies.append(np.argmin(np.linalg.norm(dataSet2-charProfile[j],axis=1)))

    collectedIndicies.append(np.flip(characteristicIndicies,axis=0))
    
    print('KMA with {} centres took {} seconds'.format(i,time.time()-timestart))
    
for i in clusterRange2:
    timestart = time.time()
    kmeans = KMeans(k=i, maxIter= 2000,featuresCol='features')
    kMeansModel = kmeans.fit(final_data)
    predictions = kMeansModel.transform(final_data).select('prediction').toPandas()
    
    # save at each stage to reduce memory consumption
    dataKey = '{}results.csv'.format(i)
    predictions.to_csv(dataKey, index=False)
    my_bucket.upload_file(dataKey,Key=resultsPath + dataKey)
    os.remove(dataKey)
    
    # Calculate Char Indicies
    profile2 = dataSet2.copy()
    profile2['labels'] = predictions.astype(np.float64)
    charProfile = profile2.groupby(['labels']).mean().values
    characteristicIndicies = []
    for j in range(i):
        characteristicIndicies.append(np.argmin(np.linalg.norm(dataSet2-charProfile[j],axis=1)))

    collectedIndicies.append(np.flip(characteristicIndicies,axis=0))
    
    print('KMA with {} centres took {} seconds'.format(i,time.time()-timestart))
    
#Uploading Char Indicies
indiciesPath = '{}/{}/{}/{}/{}/'.format(dataSource, Coor, Interp, Analysis, Indicies)
dataKey = '{}DimCharIndicies.npy'.format(Dimensions)
np.save(dataKey,collectedIndicies)
my_bucket.upload_file(dataKey,Key=indiciesPath + dataKey)
os.remove(dataKey)
# Out:
# KMA with 2 centres took 4.340428829193115 seconds
# KMA with 3 centres took 4.881385564804077 seconds
# KMA with 4 centres took 5.102336168289185 seconds
# KMA with 5 centres took 6.383940935134888 seconds
# KMA with 6 centres took 5.8996055126190186 seconds
# KMA with 7 centres took 5.906062602996826 seconds
# KMA with 8 centres took 7.4120261669158936 seconds
# KMA with 9 centres took 8.774024248123169 seconds
# KMA with 10 centres took 8.278908729553223 seconds
# KMA with 11 centres took 6.995883464813232 seconds
# KMA with 12 centres took 7.376529216766357 seconds
# KMA with 13 centres took 8.379830598831177 seconds
# KMA with 14 centres took 8.851609468460083 seconds
# KMA with 15 centres took 11.2695152759552 seconds
# KMA with 16 centres took 11.814684629440308 seconds
# KMA with 17 centres took 9.977014064788818 seconds
# KMA with 18 centres took 10.128883361816406 seconds
# KMA with 19 centres took 11.601832151412964 seconds
# KMA with 20 centres took 11.520936250686646 seconds
# KMA with 21 centres took 11.377424716949463 seconds
# KMA with 22 centres took 13.397701978683472 seconds
# KMA with 23 centres took 12.729810953140259 seconds
# KMA with 24 centres took 14.12470555305481 seconds
# KMA with 25 centres took 11.20403504371643 seconds
# KMA with 26 centres took 13.762456893920898 seconds
# KMA with 27 centres took 12.127607107162476 seconds
# KMA with 28 centres took 13.055014371871948 seconds
# KMA with 29 centres took 12.35594129562378 seconds
# KMA with 30 centres took 14.06978464126587 seconds
# KMA with 31 centres took 16.3064444065094 seconds
# KMA with 32 centres took 13.794008255004883 seconds
# KMA with 33 centres took 14.997862815856934 seconds
# KMA with 34 centres took 16.513635396957397 seconds
# KMA with 35 centres took 14.939641952514648 seconds
# KMA with 36 centres took 15.991587400436401 seconds
# KMA with 37 centres took 15.03752613067627 seconds
# KMA with 38 centres took 16.44618272781372 seconds
# KMA with 39 centres took 19.8106632232666 seconds
# KMA with 40 centres took 17.016061067581177 seconds
# KMA with 41 centres took 20.110620498657227 seconds
# KMA with 42 centres took 23.8284330368042 seconds
# KMA with 43 centres took 17.089890956878662 seconds
# KMA with 44 centres took 16.15829038619995 seconds
# KMA with 45 centres took 24.311951875686646 seconds
# KMA with 46 centres took 17.593565225601196 seconds
# KMA with 47 centres took 19.61027240753174 seconds
# KMA with 48 centres took 20.354823350906372 seconds
# KMA with 49 centres took 18.73386001586914 seconds
# KMA with 50 centres took 20.51829218864441 seconds
# KMA with 51 centres took 19.905062198638916 seconds
# KMA with 52 centres took 19.70814871788025 seconds
# KMA with 53 centres took 18.688082695007324 seconds
# KMA with 54 centres took 20.448654890060425 seconds
# KMA with 55 centres took 21.49311923980713 seconds
# KMA with 56 centres took 23.52425217628479 seconds
# KMA with 57 centres took 25.041773557662964 seconds
# KMA with 58 centres took 27.564753532409668 seconds
# KMA with 59 centres took 19.524137496948242 seconds
# KMA with 60 centres took 19.90524172782898 seconds
# KMA with 61 centres took 21.492494344711304 seconds
# KMA with 62 centres took 25.269190549850464 seconds
# KMA with 63 centres took 23.39901041984558 seconds
# KMA with 64 centres took 23.143441915512085 seconds
# KMA with 65 centres took 29.61189317703247 seconds
# KMA with 66 centres took 21.22672963142395 seconds
# KMA with 67 centres took 24.275573015213013 seconds
# KMA with 68 centres took 27.205389261245728 seconds
# KMA with 69 centres took 24.846645832061768 seconds
# KMA with 70 centres took 34.177680253982544 seconds
# KMA with 71 centres took 26.54285502433777 seconds
# KMA with 72 centres took 24.897468328475952 seconds
# KMA with 73 centres took 25.827101230621338 seconds
# KMA with 74 centres took 25.05751943588257 seconds
# KMA with 75 centres took 28.05232310295105 seconds
# KMA with 76 centres took 33.82551980018616 seconds
# KMA with 77 centres took 25.479000091552734 seconds
# KMA with 78 centres took 25.651623487472534 seconds
# KMA with 79 centres took 30.441824197769165 seconds
# KMA with 80 centres took 27.474612951278687 seconds
# KMA with 81 centres took 26.371659755706787 seconds
# KMA with 82 centres took 28.909733772277832 seconds
# KMA with 83 centres took 32.93967080116272 seconds
# KMA with 84 centres took 33.902265548706055 seconds
# KMA with 85 centres took 27.444320917129517 seconds
# KMA with 86 centres took 28.823146104812622 seconds
# KMA with 87 centres took 30.690154552459717 seconds
# KMA with 88 centres took 31.584824800491333 seconds
# KMA with 89 centres took 29.36401677131653 seconds
# KMA with 90 centres took 28.63965153694153 seconds
# KMA with 91 centres took 36.38848900794983 seconds
# KMA with 92 centres took 31.67187213897705 seconds
# KMA with 93 centres took 28.269771814346313 seconds
# KMA with 94 centres took 29.963066577911377 seconds
# KMA with 95 centres took 31.5855553150177 seconds
# KMA with 96 centres took 30.566689252853394 seconds
# KMA with 97 centres took 32.196123123168945 seconds
# KMA with 98 centres took 33.114938497543335 seconds
# KMA with 99 centres took 32.86661767959595 seconds
# KMA with 100 centres took 30.41670513153076 seconds
# KMA with 105 centres took 32.44007730484009 seconds
# KMA with 110 centres took 39.96555995941162 seconds
# KMA with 115 centres took 36.06661415100098 seconds
# KMA with 120 centres took 35.13804864883423 seconds
# KMA with 125 centres took 40.79490280151367 seconds
# KMA with 130 centres took 41.62837219238281 seconds
# KMA with 135 centres took 42.06851863861084 seconds
# KMA with 140 centres took 44.328969955444336 seconds
# KMA with 145 centres took 40.624879598617554 seconds
# KMA with 150 centres took 48.79383039474487 seconds
# KMA with 155 centres took 43.42663502693176 seconds
# KMA with 160 centres took 45.33288025856018 seconds
# KMA with 165 centres took 45.34365677833557 seconds
# KMA with 170 centres took 47.40911388397217 seconds
# KMA with 175 centres took 48.77742576599121 seconds
# KMA with 180 centres took 49.565398931503296 seconds
# KMA with 185 centres took 54.68605709075928 seconds
# KMA with 190 centres took 53.707958936691284 seconds
# KMA with 195 centres took 55.615561723709106 seconds
# KMA with 200 centres took 52.85210371017456 seconds
# KMA with 205 centres took 55.737147092819214 seconds
# KMA with 210 centres took 62.93060827255249 seconds
# KMA with 215 centres took 57.41855239868164 seconds
# KMA with 220 centres took 60.92642545700073 seconds
# KMA with 225 centres took 61.564926862716675 seconds
# KMA with 230 centres took 61.92169404029846 seconds
# KMA with 235 centres took 63.433775663375854 seconds
# KMA with 240 centres took 64.39934611320496 seconds
# KMA with 245 centres took 64.26500391960144 seconds
# KMA with 250 centres took 76.1092689037323 seconds
# KMA with 255 centres took 70.01813840866089 seconds
# KMA with 260 centres took 75.0194685459137 seconds
# KMA with 265 centres took 69.35249829292297 seconds
# KMA with 270 centres took 69.58989644050598 seconds
# KMA with 275 centres took 72.86779141426086 seconds
# KMA with 280 centres took 82.44660687446594 seconds
# KMA with 285 centres took 74.90443420410156 seconds
# KMA with 290 centres took 84.59277939796448 seconds
# KMA with 295 centres took 79.83427572250366 seconds
# KMA with 300 centres took 83.99442863464355 seconds
# KMA with 305 centres took 78.42745232582092 seconds
# KMA with 310 centres took 77.62959814071655 seconds
# KMA with 315 centres took 84.0976812839508 seconds
# KMA with 320 centres took 78.80053853988647 seconds
# KMA with 325 centres took 81.09039974212646 seconds
# KMA with 330 centres took 82.98486351966858 seconds
# KMA with 335 centres took 96.10099506378174 seconds
# KMA with 340 centres took 82.72518396377563 seconds
# KMA with 345 centres took 88.66907238960266 seconds
# KMA with 350 centres took 90.01849341392517 seconds
# KMA with 355 centres took 86.70525217056274 seconds
# KMA with 360 centres took 89.55498051643372 seconds
# KMA with 365 centres took 93.6239070892334 seconds
# KMA with 370 centres took 91.26876783370972 seconds
# KMA with 375 centres took 93.02913856506348 seconds
# KMA with 380 centres took 92.6202085018158 seconds
# KMA with 385 centres took 99.7695803642273 seconds
# KMA with 390 centres took 96.96778559684753 seconds
# KMA with 395 centres took 102.46369767189026 seconds
# KMA with 400 centres took 99.02441644668579 seconds
# KMA with 405 centres took 103.03257346153259 seconds
# KMA with 410 centres took 100.35106754302979 seconds
# KMA with 415 centres took 106.7320077419281 seconds
# KMA with 420 centres took 106.50774455070496 seconds
# KMA with 425 centres took 108.82374358177185 seconds
# KMA with 430 centres took 106.26948118209839 seconds
# KMA with 435 centres took 108.54064631462097 seconds
# KMA with 440 centres took 112.0652403831482 seconds
# KMA with 445 centres took 111.3667893409729 seconds
# KMA with 450 centres took 111.85944485664368 seconds
# KMA with 455 centres took 109.47186350822449 seconds
# KMA with 460 centres took 116.41600060462952 seconds
# KMA with 465 centres took 116.26612663269043 seconds
# KMA with 470 centres took 117.80363988876343 seconds
# KMA with 475 centres took 117.61896109580994 seconds
# KMA with 480 centres took 120.01164531707764 seconds
# KMA with 485 centres took 116.07660174369812 seconds
# KMA with 490 centres took 120.85137367248535 seconds
# KMA with 495 centres took 118.65988945960999 seconds
# KMA with 500 centres took 123.97063660621643 seconds
