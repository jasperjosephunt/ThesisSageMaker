# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('KMA').getOrCreate()
from pyspark.ml.clustering import KMeans
from pyspark.ml.feature import VectorAssembler
import os
import time
import pandas as pd

import boto3
from io import BytesIO
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role

# %%
'''
-----------------------------------------------------------------------------
--- Inptuts
-----------------------------------------------------------------------------
'''
Interp = 'Interp'
s3DataSet = 'interpDataScaledL6.csv'
Dimensions = 180

clusterRange1 = range(2,101,1)
clusterRange2 = range(105,1001,5)

# %%
'''
-----------------------------------------------------------------------------
--- Definitions
-----------------------------------------------------------------------------
'''
Results = 'Results'
Analysis = 'KMA'
resultsPath = '{}/{}/{}/{}/'.format(Results, Interp, Analysis, Dimensions)

# Configuring S3
s3_bucket_name = 'jasper-ml-sagemaker'
role = get_execution_role()

client = boto3.client('s3')
resource = boto3.resource('s3')
my_bucket = resource.Bucket(s3_bucket_name)

# %%
'''
-----------------------------------------------------------------------------
--- Importing and Vectorising Data
-----------------------------------------------------------------------------
'''
dataKey = s3DataSet
obj = client.get_object(Bucket=s3_bucket_name, Key=dataKey)
pd.read_csv(obj['Body'], header=None, index_col=None).to_csv(dataKey, index=False)
dataset = spark.read.csv(dataKey,inferSchema = True)

assembler = VectorAssembler(inputCols= dataset.columns,
                           outputCol = 'features')
final_data = assembler.transform(dataset)

'''
-----------------------------------------------------------------------------
--- Performing Clustering
-----------------------------------------------------------------------------
'''
for i in clusterRange1:
    #  Perform Kmeans on the data
    timestart = time.time()
    kmeans = KMeans(k=i, maxIter= 2000,featuresCol='features')
    kMeansModel = kmeans.fit(final_data)

    # save at each stage to reduce memory consumption
    dataKey = '{}results.csv'.format(i)
    kMeansModel.transform(final_data).select('prediction').toPandas().to_csv(dataKey, index=False)
    my_bucket.upload_file(dataKey,Key=resultsPath + dataKey)
    os.remove(dataKey)

    print('KMA with {} centres took {} seconds'.format(i,time.time()-timestart))
    
for i in clusterRange2:
    timestart = time.time()
    kmeans = KMeans(k=i, maxIter= 2000,featuresCol='features')
    kMeansModel = kmeans.fit(final_data)

    # save at each stage to reduce memory consumption
    dataKey = '{}results.csv'.format(i)
    kMeansModel.transform(final_data).select('prediction').toPandas().to_csv(dataKey, index=False)
    my_bucket.upload_file(dataKey,Key=resultsPath + dataKey)
    os.remove(dataKey)

    print('KMA with {} centres took {} seconds'.format(i,time.time()-timestart))
    
'''
-----------------------------------------------------------------------------
--- Inptuts
-----------------------------------------------------------------------------
'''
Coord = 'Polar'
Interp = 'NoInterp'
s3DataSet = 'polarDataScaledL6.csv'
Dimensions = 180

clusterRange1 = range(2,101,1)
clusterRange2 = range(105,1001,5)

'''
-----------------------------------------------------------------------------
--- Definitions
-----------------------------------------------------------------------------
'''
Results = 'Results'
Analysis = 'KMA'
resultsPath = '{}/{}/{}/{}/{}/'.format(Results, Coord, Interp, Analysis, Dimensions)

# Configuring S3
s3_bucket_name = 'jasper-ml-sagemaker'
role = get_execution_role()

client = boto3.client('s3')
resource = boto3.resource('s3')
my_bucket = resource.Bucket(s3_bucket_name)

'''
-----------------------------------------------------------------------------
--- Importing and Vectorising Data
-----------------------------------------------------------------------------
'''
dataKey = s3DataSet
obj = client.get_object(Bucket=s3_bucket_name, Key=dataKey)
pd.read_csv(obj['Body'], header=None, index_col=None).to_csv(dataKey, index=False)
dataset = spark.read.csv(dataKey,inferSchema = True)

assembler = VectorAssembler(inputCols= dataset.columns,
                           outputCol = 'features')
final_data = assembler.transform(dataset)

'''
-----------------------------------------------------------------------------
--- Performing Clustering
-----------------------------------------------------------------------------
'''
for i in clusterRange1:
    #  Perform Kmeans on the data
    timestart = time.time()
    kmeans = KMeans(k=i, maxIter= 2000,featuresCol='features')
    kMeansModel = kmeans.fit(final_data)

    # save at each stage to reduce memory consumption
    dataKey = '{}results.csv'.format(i)
    kMeansModel.transform(final_data).select('prediction').toPandas().to_csv(dataKey, index=False)
    my_bucket.upload_file(dataKey,Key=resultsPath + dataKey)
    os.remove(dataKey)

    print('KMA with {} centres took {} seconds'.format(i,time.time()-timestart))

for i in clusterRange2:
    timestart = time.time()
    kmeans = KMeans(k=i, maxIter= 2000,featuresCol='features')
    kMeansModel = kmeans.fit(final_data)

    # save at each stage to reduce memory consumption
    dataKey = '{}results.csv'.format(i)
    kMeansModel.transform(final_data).select('prediction').toPandas().to_csv(dataKey, index=False)
    my_bucket.upload_file(dataKey,Key=resultsPath + dataKey)
    os.remove(dataKey)

    print('KMA with {} centres took {} seconds'.format(i,time.time()-timestart))

'''
-----------------------------------------------------------------------------
--- Inptuts
-----------------------------------------------------------------------------
'''
Coord = 'Polar'
Interp = 'Interp'
s3DataSet = 'polarInterpDataScaledL6.csv'
Dimensions = 180

clusterRange1 = range(2,101,1)
clusterRange2 = range(105,1001,5)

'''
-----------------------------------------------------------------------------
--- Definitions
-----------------------------------------------------------------------------
'''
Results = 'Results'
Analysis = 'KMA'
resultsPath = '{}/{}/{}/{}/{}/'.format(Results, Coord, Interp, Analysis, Dimensions)

# Configuring S3
s3_bucket_name = 'jasper-ml-sagemaker'
role = get_execution_role()

client = boto3.client('s3')
resource = boto3.resource('s3')
my_bucket = resource.Bucket(s3_bucket_name)

'''
-----------------------------------------------------------------------------
--- Importing and Vectorising Data
-----------------------------------------------------------------------------
'''
dataKey = s3DataSet
obj = client.get_object(Bucket=s3_bucket_name, Key=dataKey)
pd.read_csv(obj['Body'], header=None, index_col=None).to_csv(dataKey, index=False)
dataset = spark.read.csv(dataKey,inferSchema = True)

assembler = VectorAssembler(inputCols= dataset.columns,
                           outputCol = 'features')
final_data = assembler.transform(dataset)

'''
-----------------------------------------------------------------------------
--- Performing Clustering
-----------------------------------------------------------------------------
'''
for i in clusterRange1:
    #  Perform Kmeans on the data
    timestart = time.time()
    kmeans = KMeans(k=i, maxIter= 2000,featuresCol='features')
    kMeansModel = kmeans.fit(final_data)

    # save at each stage to reduce memory consumption
    dataKey = '{}results.csv'.format(i)
    kMeansModel.transform(final_data).select('prediction').toPandas().to_csv(dataKey, index=False)
    my_bucket.upload_file(dataKey,Key=resultsPath + dataKey)
    os.remove(dataKey)

    print('KMA with {} centres took {} seconds'.format(i,time.time()-timestart))

for i in clusterRange2:
    timestart = time.time()
    kmeans = KMeans(k=i, maxIter= 2000,featuresCol='features')
    kMeansModel = kmeans.fit(final_data)

    # save at each stage to reduce memory consumption
    dataKey = '{}results.csv'.format(i)
    kMeansModel.transform(final_data).select('prediction').toPandas().to_csv(dataKey, index=False)
    my_bucket.upload_file(dataKey,Key=resultsPath + dataKey)
    os.remove(dataKey)

    print('KMA with {} centres took {} seconds'.format(i,time.time()-timestart))
# Out:
# KMA with 2 centres took 8.36699628829956 seconds
# KMA with 3 centres took 9.013299226760864 seconds
# KMA with 4 centres took 10.240257978439331 seconds
# KMA with 5 centres took 9.501990795135498 seconds
# KMA with 6 centres took 13.895456552505493 seconds
# KMA with 7 centres took 13.68198037147522 seconds
# KMA with 8 centres took 12.460870504379272 seconds
# KMA with 9 centres took 14.792114973068237 seconds
# KMA with 10 centres took 10.590485572814941 seconds
# KMA with 11 centres took 11.44452166557312 seconds
# KMA with 12 centres took 13.168226480484009 seconds
# KMA with 13 centres took 11.657974481582642 seconds
# KMA with 14 centres took 10.831020832061768 seconds
# KMA with 15 centres took 11.954235553741455 seconds
# KMA with 16 centres took 12.135224342346191 seconds
# KMA with 17 centres took 13.722691535949707 seconds
# KMA with 18 centres took 16.591112852096558 seconds
# KMA with 19 centres took 15.139440536499023 seconds
# KMA with 20 centres took 14.511483430862427 seconds
# KMA with 21 centres took 11.426872730255127 seconds
# KMA with 22 centres took 12.401195526123047 seconds
# KMA with 23 centres took 15.283817291259766 seconds
# KMA with 24 centres took 15.901938915252686 seconds
# KMA with 25 centres took 16.12634778022766 seconds
# KMA with 26 centres took 13.081665515899658 seconds
# KMA with 27 centres took 17.44670820236206 seconds
# KMA with 28 centres took 14.088380813598633 seconds
# KMA with 29 centres took 25.350390911102295 seconds
# KMA with 30 centres took 19.423031091690063 seconds
# KMA with 31 centres took 12.65378713607788 seconds
# KMA with 32 centres took 18.044263124465942 seconds
# KMA with 33 centres took 21.547584772109985 seconds
# KMA with 34 centres took 17.537549257278442 seconds
# KMA with 35 centres took 19.686593055725098 seconds
# KMA with 36 centres took 20.688069581985474 seconds
# KMA with 37 centres took 18.670918464660645 seconds
# KMA with 38 centres took 15.526310205459595 seconds
# KMA with 39 centres took 15.363855123519897 seconds
# KMA with 40 centres took 21.748061418533325 seconds
# KMA with 41 centres took 20.11670994758606 seconds
# KMA with 42 centres took 16.112745761871338 seconds
# KMA with 43 centres took 17.213143587112427 seconds
# KMA with 44 centres took 18.93043613433838 seconds
# KMA with 45 centres took 15.151201486587524 seconds
# KMA with 46 centres took 14.729179859161377 seconds
# KMA with 47 centres took 19.528230667114258 seconds
# KMA with 48 centres took 14.23112678527832 seconds
# KMA with 49 centres took 17.370821714401245 seconds
# KMA with 50 centres took 17.111449241638184 seconds
# KMA with 51 centres took 18.239882707595825 seconds
# KMA with 52 centres took 19.588219165802002 seconds
# KMA with 53 centres took 15.269920110702515 seconds
# KMA with 54 centres took 16.208616256713867 seconds
# KMA with 55 centres took 23.236136198043823 seconds
# KMA with 56 centres took 14.062329292297363 seconds
# KMA with 57 centres took 15.55615520477295 seconds
# KMA with 58 centres took 16.062034606933594 seconds
# KMA with 59 centres took 21.255141735076904 seconds
# KMA with 60 centres took 20.110737323760986 seconds
# KMA with 61 centres took 29.319522380828857 seconds
# KMA with 62 centres took 15.987650156021118 seconds
# KMA with 63 centres took 14.44727897644043 seconds
# KMA with 64 centres took 19.88991355895996 seconds
# KMA with 65 centres took 19.32024049758911 seconds
